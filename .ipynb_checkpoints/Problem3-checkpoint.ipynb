# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from matplotlib import pyplot
import math
import numpy as np
from sklearn import preprocessing

# %%
DS = pd.read_csv("C:\\Users\\dhruv\\Downloads\\Housing.csv")

# %%
train=DS.sample(frac=0.8,random_state=0) 
test=DS.drop(train.index)

# %%
DS
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
train = train[['price','area','bedrooms','bathrooms','stories','parking']]
test = test[['price','area','bedrooms','bathrooms','stories','parking']]

# %%
scaler = preprocessing.MinMaxScaler()

# %%
X1_t = np.array(train.area)
X2_t = np.array(train.bedrooms)
X3_t = np.array(train.bathrooms)
X4_t = np.array(train.stories)
X5_t = np.array(train.parking)

X0_t= np.ones(436)

X = np.vstack([X0_t,X1_t,X2_t,X3_t,X4_t,X5_t])
X = X.T
X = np.array(X)   
x = scaler.fit_transform(X)
X= x
X
# Out:
# array([[0.        , 0.16151203, 0.4       , 0.        , 0.33333333,
#         0.33333333],
#        [0.        , 0.54776632, 0.4       , 0.        , 0.        ,
#         0.66666667],
#        [0.        , 0.12439863, 0.6       , 0.        , 0.33333333,
#         0.        ],
#        ...,
#        [0.        , 0.13402062, 0.4       , 0.        , 0.33333333,
#         0.33333333],
#        [0.        , 0.08247423, 0.4       , 0.33333333, 0.33333333,
#         0.        ],
#        [0.        , 0.21649485, 0.4       , 0.        , 0.        ,
#         0.        ]])

# %%
Y_t = np.array(train.price)
Y = Y_t
Y = Y_t.reshape(436,1)
y = scaler.fit_transform(Y)
Y=y

# %%
#weights and bias column
theta = np.array([0., 0., 0., 0., 0., 0.])
theta = theta.reshape(6,1)
theta
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
#Data Array
t_c = Y #PRICE(Actual Y's or Data(price))
t_u = X #Epochs(Actual X's ...multidimentional)

# %%
t_c = torch.tensor(t_c, dtype=torch.float64)#.to_numpy()
t_u = torch.tensor(t_u, dtype=torch.float64)

# %%
t_c= np.array(t_c)
t_u= np.array(t_u)
t_c = torch.tensor(t_c)
t_u = torch.tensor(t_u)

# %%
#Weights and Bias as column
b = torch.zeros(1)
w5 = torch.ones(1)
w4 = torch.ones(1)
w3 = torch.ones(1)
w2 = torch.ones(1)
w1 = torch.ones(1)

# %%
theta = [b, w1,w2, w3, w4, w5]
theta = torch.tensor(theta).reshape(6,1)

# %%
#Model definition linear
def model(X, theta):
    return np.matmul(X, theta)

# %%
#Loss function
def loss_func(t_p, t_c):
    var = (t_p - t_c)**2
    return var.mean()

# %%
t_p = model(X, theta)
#t_p = torch.tensor(t_p)

# %%
loss = loss_func(t_p, t_c)
loss
# Out:
# tensor(1.1408, dtype=torch.float64)

# %%
def b_del(delta):
    b_del = [delta, 0,0,0,0,0]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del
def w5_del(delta):
    b_del = [0, delta,0,0,0,0]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del
def w4_del(delta):
    b_del = [0, 0,delta,0,0,0]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del
def w3_del(delta):
    b_del = [0, 0,0,delta,0,0]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del
def w2_del(delta):
    b_del = [0, 0,0,0,delta,0]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del
def w1_del(delta):
    b_del = [0, 0,0,0,0,delta]
    b_del = torch.tensor(b_del).reshape(6,1)
    return b_del

# %%
delta = 0.7

loss_rate_of_change_b = (loss_func(model(t_u, theta+b_del(delta)), t_c) - 
loss_func(model(t_u, theta-b_del(delta)), t_c))/(2.0 * delta)

loss_rate_of_change_w1 = (loss_func(model(t_u, theta+w1_del(delta)), t_c) - 
loss_func(model(t_u, theta-w1_del(delta)), t_c))/(2.0 * delta)

loss_rate_of_change_w2 = (loss_func(model(t_u, theta+w2_del(delta)), t_c) - 
loss_func(model(t_u, theta-w2_del(delta)), t_c))/(2.0 * delta)

loss_rate_of_change_w3 = (loss_func(model(t_u, theta+w3_del(delta)), t_c) - 
loss_func(model(t_u, theta-w3_del(delta)), t_c))/(2.0 * delta)

loss_rate_of_change_w4 = (loss_func(model(t_u, theta+w4_del(delta)), t_c) - 
loss_func(model(t_u, theta-w4_del(delta)), t_c))/(2.0 * delta)

loss_rate_of_change_w5 = (loss_func(model(t_u, theta+w5_del(delta)), t_c) - 
loss_func(model(t_u, theta-w5_del(delta)), t_c))/(2.0 * delta)

# %%
learning_rate = 1e-2
w1 = w1 - learning_rate * loss_rate_of_change_w1
w2 = w2 - learning_rate * loss_rate_of_change_w2
w3 = w3 - learning_rate * loss_rate_of_change_w3
w4 = w4 - learning_rate * loss_rate_of_change_w4
w5 = w5 - learning_rate * loss_rate_of_change_w5
b = b - learning_rate * loss_rate_of_change_b

# %%
#Partial deriv of loss function 
def dloss_fn(t_p, t_c):
    dsq_diffs=2* (t_p - t_c) / t_p.size(0)
    return dsq_diffs

# %%
#dm/dw5
def dmodel_dw5(t_u, w5, w4, w3, w2, w1, b):
    return t_u

# %%
#dm/dw4
def dmodel_dw4(t_u, w5, w4, w3, w2, w1, b):
    return t_u

# %%
#dm/dw3
def dmodel_dw3(t_u, w5, w4, w3, w2, w1, b):
    return t_u

# %%
#dm/dw2
def dmodel_dw2(t_u, w5, w4, w3, w2, w1, b):
    return t_u

# %%
#dm/dw1
def dmodel_dw1(t_u, w5, w4, w3, w2, w1, b):
    return t_u

# %%
#dm/db
def dmodel_db(t_u, w5, w4, w3, w2, w1, b):
    return 1.0

# %%
def grad_fn(t_u, t_c, t_p, w5, w4, w3, w2, w1, b):
    dloss_dtp = dloss_fn(t_p, t_c)
    dloss_dw5 = dloss_dtp * dmodel_dw2(t_u, w5, w4, w3, w2, w1, b)
    dloss_dw4 = dloss_dtp * dmodel_dw1(t_u, w5, w4, w3, w2, w1, b)
    dloss_dw3 = dloss_dtp * dmodel_db(t_u, w5, w4, w3, w2, w1, b)
    dloss_dw2 = dloss_dtp * dmodel_dw2(t_u, w5, w4, w3, w2, w1, b)
    dloss_dw1 = dloss_dtp * dmodel_dw1(t_u, w5, w4, w3, w2, w1, b)
    dloss_db = dloss_dtp * dmodel_db(t_u, w5, w4, w3, w2, w1, b)
    return torch.stack([dloss_dw5.sum(), dloss_dw4.sum(), dloss_dw3.sum(), dloss_dw2.sum(), dloss_dw1.sum(), dloss_db.sum()])

# %%
def training_loop(n_epochs, learning_rate, params, t_u, t_c):
    for epoch in range(1, n_epochs + 1):
        w5, w4, w3, w2, w1, b = params
        theta = [b, w1,w2, w3, w4, w5]
        theta = torch.tensor(theta).reshape(6,1)
        t_p = model(t_u, theta)
        loss = loss_func(t_p, t_c)
        grad = grad_fn(t_u, t_c, t_p, w5, w4, w3, w2, w1, b)
        params = params - learning_rate * grad
        print('Epoch %d, Loss %f' % (epoch, float(loss)))
        print('Params: %f', params)
        print("Grad: %f", grad)
        print('-------------------------------------------------')
    return params

# %%
#In this part I was getting na numbers...I HAD to reduce the learning rate to that level......
#rest of the training for LR=0.1,0.01,0.001,0.0001 is done in the following sub-parts of the HW like Problem 1.1,1.2,etc.
training_loop(
n_epochs = 5000,
learning_rate = 1e-3,
params = torch.tensor([1,1,1,0.5, 0.1, 0.5]),
t_u = t_u,
t_c = t_c)
# Out:
# Epoch 1, Loss 0.454918
# Params: %f tensor([0.9982, 0.9982, 0.9990, 0.4982, 0.0982, 0.4990], dtype=torch.float64)
# Grad: %f tensor([1.7521, 1.7521, 1.0286, 1.7521, 1.7521, 1.0286], dtype=torch.float64)
# -------------------------------------------------
# Epoch 2, Loss 0.451987
# Params: %f tensor([0.9965, 0.9965, 0.9979, 0.4965, 0.0965, 0.4979], dtype=torch.float64)
# Grad: %f tensor([1.7458, 1.7458, 1.0245, 1.7458, 1.7458, 1.0245], dtype=torch.float64)
# -------------------------------------------------
# Epoch 3, Loss 0.449078
# Params: %f tensor([0.9948, 0.9948, 0.9969, 0.4948, 0.0948, 0.4969], dtype=torch.float64)
# Grad: %f tensor([1.7395, 1.7395, 1.0204, 1.7395, 1.7395, 1.0204], dtype=torch.float64)
# -------------------------------------------------
# Epoch 4, Loss 0.446190
# Params: %f tensor([0.9930, 0.9930, 0.9959, 0.4930, 0.0930, 0.4959], dtype=torch.float64)
# Grad: %f tensor([1.7332, 1.7332, 1.0163, 1.7332, 1.7332, 1.0163], dtype=torch.float64)
# -------------------------------------------------
# Epoch 5, Loss 0.443322
# Params: %f tensor([0.9913, 0.9913, 0.9949, 0.4913, 0.0913, 0.4949], dtype=torch.float64)
# Grad: %f tensor([1.7269, 1.7269, 1.0122, 1.7269, 1.7269, 1.0122], dtype=torch.float64)
# -------------------------------------------------
# Epoch 6, Loss 0.440476
# Params: %f tensor([0.9896, 0.9896, 0.9939, 0.4896, 0.0896, 0.4939], dtype=torch.float64)
# Grad: %f tensor([1.7206, 1.7206, 1.0081, 1.7206, 1.7206, 1.0081], dtype=torch.float64)
# -------------------------------------------------
# Epoch 7, Loss 0.437650
# Params: %f tensor([0.9879, 0.9879, 0.9929, 0.4879, 0.0879, 0.4929], dtype=torch.float64)
# Grad: %f tensor([1.7144, 1.7144, 1.0041, 1.7144, 1.7144, 1.0041], dtype=torch.float64)
# -------------------------------------------------
# Epoch 8, Loss 0.434845
# Params: %f tensor([0.9862, 0.9862, 0.9919, 0.4862, 0.0862, 0.4919], dtype=torch.float64)
# Grad: %f tensor([1.7082, 1.7082, 1.0001, 1.7082, 1.7082, 1.0001], dtype=torch.float64)
# -------------------------------------------------
# Epoch 9, Loss 0.432060
# Params: %f tensor([0.9845, 0.9845, 0.9909, 0.4845, 0.0845, 0.4909], dtype=torch.float64)
# Grad: %f tensor([1.7020, 1.7020, 0.9960, 1.7020, 1.7020, 0.9960], dtype=torch.float64)
# -------------------------------------------------
# Epoch 10, Loss 0.429296
# Params: %f tensor([0.9828, 0.9828, 0.9899, 0.4828, 0.0828, 0.4899], dtype=torch.float64)
# Grad: %f tensor([1.6959, 1.6959, 0.9920, 1.6959, 1.6959, 0.9920], dtype=torch.float64)
# -------------------------------------------------
# Epoch 11, Loss 0.426552
# Params: %f tensor([0.9811, 0.9811, 0.9889, 0.4811, 0.0811, 0.4889], dtype=torch.float64)
# Grad: %f tensor([1.6897, 1.6897, 0.9880, 1.6897, 1.6897, 0.9880], dtype=torch.float64)
# -------------------------------------------------
# Epoch 12, Loss 0.423827
# Params: %f tensor([0.9794, 0.9794, 0.9879, 0.4794, 0.0794, 0.4879], dtype=torch.float64)
# Grad: %f tensor([1.6836, 1.6836, 0.9841, 1.6836, 1.6836, 0.9841], dtype=torch.float64)
# -------------------------------------------------
# Epoch 13, Loss 0.421123
# Params: %f tensor([0.9777, 0.9777, 0.9869, 0.4777, 0.0777, 0.4869], dtype=torch.float64)
# Grad: %f tensor([1.6775, 1.6775, 0.9801, 1.6775, 1.6775, 0.9801], dtype=torch.float64)
# -------------------------------------------------
# Epoch 14, Loss 0.418438
# Params: %f tensor([0.9760, 0.9760, 0.9860, 0.4760, 0.0760, 0.4860], dtype=torch.float64)
# Grad: %f tensor([1.6714, 1.6714, 0.9762, 1.6714, 1.6714, 0.9762], dtype=torch.float64)
# -------------------------------------------------
# Epoch 15, Loss 0.415772
# Params: %f tensor([0.9744, 0.9744, 0.9850, 0.4744, 0.0744, 0.4850], dtype=torch.float64)
# Grad: %f tensor([1.6654, 1.6654, 0.9722, 1.6654, 1.6654, 0.9722], dtype=torch.float64)
# -------------------------------------------------
# Epoch 16, Loss 0.413126
# Params: %f tensor([0.9727, 0.9727, 0.9840, 0.4727, 0.0727, 0.4840], dtype=torch.float64)
# Grad: %f tensor([1.6593, 1.6593, 0.9683, 1.6593, 1.6593, 0.9683], dtype=torch.float64)
# -------------------------------------------------
# Epoch 17, Loss 0.410500
# Params: %f tensor([0.9711, 0.9711, 0.9831, 0.4711, 0.0711, 0.4831], dtype=torch.float64)
# Grad: %f tensor([1.6533, 1.6533, 0.9644, 1.6533, 1.6533, 0.9644], dtype=torch.float64)
# -------------------------------------------------
# Epoch 18, Loss 0.407892
# Params: %f tensor([0.9694, 0.9694, 0.9821, 0.4694, 0.0694, 0.4821], dtype=torch.float64)
# Grad: %f tensor([1.6474, 1.6474, 0.9605, 1.6474, 1.6474, 0.9605], dtype=torch.float64)
# -------------------------------------------------
# Epoch 19, Loss 0.405303
# Params: %f tensor([0.9678, 0.9678, 0.9811, 0.4678, 0.0678, 0.4811], dtype=torch.float64)
# Grad: %f tensor([1.6414, 1.6414, 0.9566, 1.6414, 1.6414, 0.9566], dtype=torch.float64)
# -------------------------------------------------
# Epoch 20, Loss 0.402733
# Params: %f tensor([0.9661, 0.9661, 0.9802, 0.4661, 0.0661, 0.4802], dtype=torch.float64)
# Grad: %f tensor([1.6355, 1.6355, 0.9528, 1.6355, 1.6355, 0.9528], dtype=torch.float64)
# -------------------------------------------------
# Epoch 21, Loss 0.400182
# Params: %f tensor([0.9645, 0.9645, 0.9792, 0.4645, 0.0645, 0.4792], dtype=torch.float64)
# Grad: %f tensor([1.6295, 1.6295, 0.9489, 1.6295, 1.6295, 0.9489], dtype=torch.float64)
# -------------------------------------------------
# Epoch 22, Loss 0.397649
# Params: %f tensor([0.9629, 0.9629, 0.9783, 0.4629, 0.0629, 0.4783], dtype=torch.float64)
# Grad: %f tensor([1.6236, 1.6236, 0.9451, 1.6236, 1.6236, 0.9451], dtype=torch.float64)
# -------------------------------------------------
# Epoch 23, Loss 0.395135
# Params: %f tensor([0.9613, 0.9613, 0.9774, 0.4613, 0.0613, 0.4774], dtype=torch.float64)
# Grad: %f tensor([1.6178, 1.6178, 0.9413, 1.6178, 1.6178, 0.9413], dtype=torch.float64)
# -------------------------------------------------
# Epoch 24, Loss 0.392639
# Params: %f tensor([0.9597, 0.9597, 0.9764, 0.4597, 0.0597, 0.4764], dtype=torch.float64)
# Grad: %f tensor([1.6119, 1.6119, 0.9375, 1.6119, 1.6119, 0.9375], dtype=torch.float64)
# -------------------------------------------------
# Epoch 25, Loss 0.390161
# Params: %f tensor([0.9580, 0.9580, 0.9755, 0.4580, 0.0580, 0.4755], dtype=torch.float64)
# Grad: %f tensor([1.6061, 1.6061, 0.9337, 1.6061, 1.6061, 0.9337], dtype=torch.float64)
# -------------------------------------------------
# Epoch 26, Loss 0.387702
# Params: %f tensor([0.9564, 0.9564, 0.9746, 0.4564, 0.0564, 0.4746], dtype=torch.float64)
# Grad: %f tensor([1.6003, 1.6003, 0.9299, 1.6003, 1.6003, 0.9299], dtype=torch.float64)
# -------------------------------------------------
# Epoch 27, Loss 0.385260
# Params: %f tensor([0.9549, 0.9549, 0.9736, 0.4549, 0.0549, 0.4736], dtype=torch.float64)
# Grad: %f tensor([1.5945, 1.5945, 0.9261, 1.5945, 1.5945, 0.9261], dtype=torch.float64)
# -------------------------------------------------
# Epoch 28, Loss 0.382836
# Params: %f tensor([0.9533, 0.9533, 0.9727, 0.4533, 0.0533, 0.4727], dtype=torch.float64)
# Grad: %f tensor([1.5887, 1.5887, 0.9224, 1.5887, 1.5887, 0.9224], dtype=torch.float64)
# -------------------------------------------------
# Epoch 29, Loss 0.380429
# Params: %f tensor([0.9517, 0.9517, 0.9718, 0.4517, 0.0517, 0.4718], dtype=torch.float64)
# Grad: %f tensor([1.5829, 1.5829, 0.9187, 1.5829, 1.5829, 0.9187], dtype=torch.float64)
# -------------------------------------------------
# Epoch 30, Loss 0.378040
# Params: %f tensor([0.9501, 0.9501, 0.9709, 0.4501, 0.0501, 0.4709], dtype=torch.float64)
# Grad: %f tensor([1.5772, 1.5772, 0.9149, 1.5772, 1.5772, 0.9149], dtype=torch.float64)
# -------------------------------------------------
# Epoch 31, Loss 0.375669
# Params: %f tensor([0.9485, 0.9485, 0.9700, 0.4485, 0.0485, 0.4700], dtype=torch.float64)
# Grad: %f tensor([1.5715, 1.5715, 0.9112, 1.5715, 1.5715, 0.9112], dtype=torch.float64)
# -------------------------------------------------
# Epoch 32, Loss 0.373314
# Params: %f tensor([0.9470, 0.9470, 0.9691, 0.4470, 0.0470, 0.4691], dtype=torch.float64)
# Grad: %f tensor([1.5658, 1.5658, 0.9075, 1.5658, 1.5658, 0.9075], dtype=torch.float64)
# -------------------------------------------------
# Epoch 33, Loss 0.370977
# Params: %f tensor([0.9454, 0.9454, 0.9682, 0.4454, 0.0454, 0.4682], dtype=torch.float64)
# Grad: %f tensor([1.5602, 1.5602, 0.9038, 1.5602, 1.5602, 0.9038], dtype=torch.float64)
# -------------------------------------------------
# Epoch 34, Loss 0.368657
# Params: %f tensor([0.9439, 0.9439, 0.9673, 0.4439, 0.0439, 0.4673], dtype=torch.float64)
# Grad: %f tensor([1.5545, 1.5545, 0.9002, 1.5545, 1.5545, 0.9002], dtype=torch.float64)
# -------------------------------------------------
# Epoch 35, Loss 0.366353
# Params: %f tensor([0.9423, 0.9423, 0.9664, 0.4423, 0.0423, 0.4664], dtype=torch.float64)
# Grad: %f tensor([1.5489, 1.5489, 0.8965, 1.5489, 1.5489, 0.8965], dtype=torch.float64)
# -------------------------------------------------
# Epoch 36, Loss 0.364067
# Params: %f tensor([0.9408, 0.9408, 0.9655, 0.4408, 0.0408, 0.4655], dtype=torch.float64)
# Grad: %f tensor([1.5433, 1.5433, 0.8929, 1.5433, 1.5433, 0.8929], dtype=torch.float64)
# -------------------------------------------------
# Epoch 37, Loss 0.361797
# Params: %f tensor([0.9392, 0.9392, 0.9646, 0.4392, 0.0392, 0.4646], dtype=torch.float64)
# Grad: %f tensor([1.5377, 1.5377, 0.8892, 1.5377, 1.5377, 0.8892], dtype=torch.float64)
# -------------------------------------------------
# Epoch 38, Loss 0.359543
# Params: %f tensor([0.9377, 0.9377, 0.9637, 0.4377, 0.0377, 0.4637], dtype=torch.float64)
# Grad: %f tensor([1.5321, 1.5321, 0.8856, 1.5321, 1.5321, 0.8856], dtype=torch.float64)
# -------------------------------------------------
# Epoch 39, Loss 0.357306
# Params: %f tensor([0.9362, 0.9362, 0.9628, 0.4362, 0.0362, 0.4628], dtype=torch.float64)
# Grad: %f tensor([1.5266, 1.5266, 0.8820, 1.5266, 1.5266, 0.8820], dtype=torch.float64)
# -------------------------------------------------
# Epoch 40, Loss 0.355085
# Params: %f tensor([0.9346, 0.9346, 0.9619, 0.4346, 0.0346, 0.4619], dtype=torch.float64)
# Grad: %f tensor([1.5211, 1.5211, 0.8784, 1.5211, 1.5211, 0.8784], dtype=torch.float64)
# -------------------------------------------------
# Epoch 41, Loss 0.352881
# Params: %f tensor([0.9331, 0.9331, 0.9611, 0.4331, 0.0331, 0.4611], dtype=torch.float64)
# Grad: %f tensor([1.5156, 1.5156, 0.8749, 1.5156, 1.5156, 0.8749], dtype=torch.float64)
# -------------------------------------------------
# Epoch 42, Loss 0.350692
# Params: %f tensor([0.9316, 0.9316, 0.9602, 0.4316, 0.0316, 0.4602], dtype=torch.float64)
# Grad: %f tensor([1.5101, 1.5101, 0.8713, 1.5101, 1.5101, 0.8713], dtype=torch.float64)
# -------------------------------------------------
# Epoch 43, Loss 0.348519
# Params: %f tensor([0.9301, 0.9301, 0.9593, 0.4301, 0.0301, 0.4593], dtype=torch.float64)
# Grad: %f tensor([1.5046, 1.5046, 0.8677, 1.5046, 1.5046, 0.8677], dtype=torch.float64)
# -------------------------------------------------
# Epoch 44, Loss 0.346362
# Params: %f tensor([0.9286, 0.9286, 0.9585, 0.4286, 0.0286, 0.4585], dtype=torch.float64)
# Grad: %f tensor([1.4992, 1.4992, 0.8642, 1.4992, 1.4992, 0.8642], dtype=torch.float64)
# -------------------------------------------------
# Epoch 45, Loss 0.344221
# Params: %f tensor([0.9271, 0.9271, 0.9576, 0.4271, 0.0271, 0.4576], dtype=torch.float64)
# Grad: %f tensor([1.4938, 1.4938, 0.8607, 1.4938, 1.4938, 0.8607], dtype=torch.float64)
# -------------------------------------------------
# Epoch 46, Loss 0.342095
# Params: %f tensor([0.9256, 0.9256, 0.9567, 0.4256, 0.0256, 0.4567], dtype=torch.float64)
# Grad: %f tensor([1.4884, 1.4884, 0.8572, 1.4884, 1.4884, 0.8572], dtype=torch.float64)
# -------------------------------------------------
# Epoch 47, Loss 0.339985
# Params: %f tensor([0.9241, 0.9241, 0.9559, 0.4241, 0.0241, 0.4559], dtype=torch.float64)
# Grad: %f tensor([1.4830, 1.4830, 0.8537, 1.4830, 1.4830, 0.8537], dtype=torch.float64)
# -------------------------------------------------
# Epoch 48, Loss 0.337890
# Params: %f tensor([0.9227, 0.9227, 0.9550, 0.4227, 0.0227, 0.4550], dtype=torch.float64)
# Grad: %f tensor([1.4776, 1.4776, 0.8502, 1.4776, 1.4776, 0.8502], dtype=torch.float64)
# -------------------------------------------------
# Epoch 49, Loss 0.335811
# Params: %f tensor([0.9212, 0.9212, 0.9542, 0.4212, 0.0212, 0.4542], dtype=torch.float64)
# Grad: %f tensor([1.4723, 1.4723, 0.8467, 1.4723, 1.4723, 0.8467], dtype=torch.float64)
# -------------------------------------------------
# Epoch 50, Loss 0.333746
# Params: %f tensor([0.9197, 0.9197, 0.9533, 0.4197, 0.0197, 0.4533], dtype=torch.float64)
# Grad: %f tensor([1.4669, 1.4669, 0.8433, 1.4669, 1.4669, 0.8433], dtype=torch.float64)
# -------------------------------------------------
# Epoch 51, Loss 0.331697
# Params: %f tensor([0.9183, 0.9183, 0.9525, 0.4183, 0.0183, 0.4525], dtype=torch.float64)
# Grad: %f tensor([1.4616, 1.4616, 0.8398, 1.4616, 1.4616, 0.8398], dtype=torch.float64)
# -------------------------------------------------
# Epoch 52, Loss 0.329662
# Params: %f tensor([0.9168, 0.9168, 0.9517, 0.4168, 0.0168, 0.4517], dtype=torch.float64)
# Grad: %f tensor([1.4563, 1.4563, 0.8364, 1.4563, 1.4563, 0.8364], dtype=torch.float64)
# -------------------------------------------------
# Epoch 53, Loss 0.327642
# Params: %f tensor([0.9154, 0.9154, 0.9508, 0.4154, 0.0154, 0.4508], dtype=torch.float64)
# Grad: %f tensor([1.4511, 1.4511, 0.8329, 1.4511, 1.4511, 0.8329], dtype=torch.float64)
# -------------------------------------------------
# Epoch 54, Loss 0.325637
# Params: %f tensor([0.9139, 0.9139, 0.9500, 0.4139, 0.0139, 0.4500], dtype=torch.float64)
# Grad: %f tensor([1.4458, 1.4458, 0.8295, 1.4458, 1.4458, 0.8295], dtype=torch.float64)
# -------------------------------------------------
# Epoch 55, Loss 0.323647
# Params: %f tensor([0.9125, 0.9125, 0.9492, 0.4125, 0.0125, 0.4492], dtype=torch.float64)
# Grad: %f tensor([1.4406, 1.4406, 0.8261, 1.4406, 1.4406, 0.8261], dtype=torch.float64)
# -------------------------------------------------
# Epoch 56, Loss 0.321671
# Params: %f tensor([0.9110, 0.9110, 0.9484, 0.4110, 0.0110, 0.4484], dtype=torch.float64)
# Grad: %f tensor([1.4354, 1.4354, 0.8227, 1.4354, 1.4354, 0.8227], dtype=torch.float64)
# -------------------------------------------------
# Epoch 57, Loss 0.319709
# Params: %f tensor([0.9096, 0.9096, 0.9475, 0.4096, 0.0096, 0.4475], dtype=torch.float64)
# Grad: %f tensor([1.4302, 1.4302, 0.8194, 1.4302, 1.4302, 0.8194], dtype=torch.float64)
# -------------------------------------------------
# Epoch 58, Loss 0.317762
# Params: %f tensor([0.9082, 0.9082, 0.9467, 0.4082, 0.0082, 0.4467], dtype=torch.float64)
# Grad: %f tensor([1.4250, 1.4250, 0.8160, 1.4250, 1.4250, 0.8160], dtype=torch.float64)
# -------------------------------------------------
# Epoch 59, Loss 0.315829
# Params: %f tensor([0.9068, 0.9068, 0.9459, 0.4068, 0.0068, 0.4459], dtype=torch.float64)
# Grad: %f tensor([1.4199, 1.4199, 0.8127, 1.4199, 1.4199, 0.8127], dtype=torch.float64)
# -------------------------------------------------
# Epoch 60, Loss 0.313909
# Params: %f tensor([0.9054, 0.9054, 0.9451, 0.4054, 0.0054, 0.4451], dtype=torch.float64)
# Grad: %f tensor([1.4147, 1.4147, 0.8093, 1.4147, 1.4147, 0.8093], dtype=torch.float64)
# -------------------------------------------------
# Epoch 61, Loss 0.312004
# Params: %f tensor([0.9039, 0.9039, 0.9443, 0.4039, 0.0039, 0.4443], dtype=torch.float64)
# Grad: %f tensor([1.4096, 1.4096, 0.8060, 1.4096, 1.4096, 0.8060], dtype=torch.float64)
# -------------------------------------------------
# Epoch 62, Loss 0.310113
# Params: %f tensor([0.9025, 0.9025, 0.9435, 0.4025, 0.0025, 0.4435], dtype=torch.float64)
# Grad: %f tensor([1.4045, 1.4045, 0.8027, 1.4045, 1.4045, 0.8027], dtype=torch.float64)
# -------------------------------------------------
# Epoch 63, Loss 0.308235
# Params: %f tensor([0.9011, 0.9011, 0.9427, 0.4011, 0.0011, 0.4427], dtype=torch.float64)
# Grad: %f tensor([1.3995, 1.3995, 0.7994, 1.3995, 1.3995, 0.7994], dtype=torch.float64)
# -------------------------------------------------
# Epoch 64, Loss 0.306371
# Params: %f tensor([ 8.9974e-01,  8.9974e-01,  9.4189e-01,  3.9974e-01, -2.5727e-04,
#          4.4189e-01], dtype=torch.float64)
# Grad: %f tensor([1.3944, 1.3944, 0.7961, 1.3944, 1.3944, 0.7961], dtype=torch.float64)
# -------------------------------------------------
# Epoch 65, Loss 0.304521
# Params: %f tensor([ 0.8984,  0.8984,  0.9411,  0.3984, -0.0016,  0.4411],
#        dtype=torch.float64)
# Grad: %f tensor([1.3894, 1.3894, 0.7928, 1.3894, 1.3894, 0.7928], dtype=torch.float64)
# -------------------------------------------------
# Epoch 66, Loss 0.302684
# Params: %f tensor([ 0.8970,  0.8970,  0.9403,  0.3970, -0.0030,  0.4403],
#        dtype=torch.float64)
# Grad: %f tensor([1.3843, 1.3843, 0.7896, 1.3843, 1.3843, 0.7896], dtype=torch.float64)
# -------------------------------------------------
# Epoch 67, Loss 0.300860
# Params: %f tensor([ 0.8956,  0.8956,  0.9395,  0.3956, -0.0044,  0.4395],
#        dtype=torch.float64)
# Grad: %f tensor([1.3793, 1.3793, 0.7863, 1.3793, 1.3793, 0.7863], dtype=torch.float64)
# -------------------------------------------------
# Epoch 68, Loss 0.299050
# Params: %f tensor([ 0.8942,  0.8942,  0.9387,  0.3942, -0.0058,  0.4387],
#        dtype=torch.float64)
# Grad: %f tensor([1.3743, 1.3743, 0.7831, 1.3743, 1.3743, 0.7831], dtype=torch.float64)
# -------------------------------------------------
# Epoch 69, Loss 0.297253
# Params: %f tensor([ 0.8928,  0.8928,  0.9380,  0.3928, -0.0072,  0.4380],
#        dtype=torch.float64)
# Grad: %f tensor([1.3694, 1.3694, 0.7798, 1.3694, 1.3694, 0.7798], dtype=torch.float64)
# -------------------------------------------------
# Epoch 70, Loss 0.295469
# Params: %f tensor([ 0.8915,  0.8915,  0.9372,  0.3915, -0.0085,  0.4372],
#        dtype=torch.float64)
# Grad: %f tensor([1.3644, 1.3644, 0.7766, 1.3644, 1.3644, 0.7766], dtype=torch.float64)
# -------------------------------------------------
# Epoch 71, Loss 0.293698
# Params: %f tensor([ 0.8901,  0.8901,  0.9364,  0.3901, -0.0099,  0.4364],
#        dtype=torch.float64)
# Grad: %f tensor([1.3595, 1.3595, 0.7734, 1.3595, 1.3595, 0.7734], dtype=torch.float64)
# -------------------------------------------------
# Epoch 72, Loss 0.291940
# Params: %f tensor([ 0.8888,  0.8888,  0.9356,  0.3888, -0.0112,  0.4356],
#        dtype=torch.float64)
# Grad: %f tensor([1.3546, 1.3546, 0.7702, 1.3546, 1.3546, 0.7702], dtype=torch.float64)
# -------------------------------------------------
# Epoch 73, Loss 0.290194
# Params: %f tensor([ 0.8874,  0.8874,  0.9349,  0.3874, -0.0126,  0.4349],
#        dtype=torch.float64)
# Grad: %f tensor([1.3497, 1.3497, 0.7670, 1.3497, 1.3497, 0.7670], dtype=torch.float64)
# -------------------------------------------------
# Epoch 74, Loss 0.288462
# Params: %f tensor([ 0.8861,  0.8861,  0.9341,  0.3861, -0.0139,  0.4341],
#        dtype=torch.float64)
# Grad: %f tensor([1.3448, 1.3448, 0.7639, 1.3448, 1.3448, 0.7639], dtype=torch.float64)
# -------------------------------------------------
# Epoch 75, Loss 0.286741
# Params: %f tensor([ 0.8847,  0.8847,  0.9333,  0.3847, -0.0153,  0.4333],
#        dtype=torch.float64)
# Grad: %f tensor([1.3399, 1.3399, 0.7607, 1.3399, 1.3399, 0.7607], dtype=torch.float64)
# -------------------------------------------------
# Epoch 76, Loss 0.285034
# Params: %f tensor([ 0.8834,  0.8834,  0.9326,  0.3834, -0.0166,  0.4326],
#        dtype=torch.float64)
# Grad: %f tensor([1.3351, 1.3351, 0.7576, 1.3351, 1.3351, 0.7576], dtype=torch.float64)
# -------------------------------------------------
# Epoch 77, Loss 0.283339
# Params: %f tensor([ 0.8821,  0.8821,  0.9318,  0.3821, -0.0179,  0.4318],
#        dtype=torch.float64)
# Grad: %f tensor([1.3303, 1.3303, 0.7544, 1.3303, 1.3303, 0.7544], dtype=torch.float64)
# -------------------------------------------------
# Epoch 78, Loss 0.281656
# Params: %f tensor([ 0.8807,  0.8807,  0.9311,  0.3807, -0.0193,  0.4311],
#        dtype=torch.float64)
# Grad: %f tensor([1.3255, 1.3255, 0.7513, 1.3255, 1.3255, 0.7513], dtype=torch.float64)
# -------------------------------------------------
# Epoch 79, Loss 0.279985
# Params: %f tensor([ 0.8794,  0.8794,  0.9303,  0.3794, -0.0206,  0.4303],
#        dtype=torch.float64)
# Grad: %f tensor([1.3207, 1.3207, 0.7482, 1.3207, 1.3207, 0.7482], dtype=torch.float64)
# -------------------------------------------------
# Epoch 80, Loss 0.278327
# Params: %f tensor([ 0.8781,  0.8781,  0.9296,  0.3781, -0.0219,  0.4296],
#        dtype=torch.float64)
# Grad: %f tensor([1.3159, 1.3159, 0.7451, 1.3159, 1.3159, 0.7451], dtype=torch.float64)
# -------------------------------------------------
# Epoch 81, Loss 0.276680
# Params: %f tensor([ 0.8768,  0.8768,  0.9288,  0.3768, -0.0232,  0.4288],
#        dtype=torch.float64)
# Grad: %f tensor([1.3111, 1.3111, 0.7420, 1.3111, 1.3111, 0.7420], dtype=torch.float64)
# -------------------------------------------------
# Epoch 82, Loss 0.275046
# Params: %f tensor([ 0.8755,  0.8755,  0.9281,  0.3755, -0.0245,  0.4281],
#        dtype=torch.float64)
# Grad: %f tensor([1.3064, 1.3064, 0.7389, 1.3064, 1.3064, 0.7389], dtype=torch.float64)
# -------------------------------------------------
# Epoch 83, Loss 0.273423
# Params: %f tensor([ 0.8742,  0.8742,  0.9274,  0.3742, -0.0258,  0.4274],
#        dtype=torch.float64)
# Grad: %f tensor([1.3017, 1.3017, 0.7358, 1.3017, 1.3017, 0.7358], dtype=torch.float64)
# -------------------------------------------------
# Epoch 84, Loss 0.271813
# Params: %f tensor([ 0.8729,  0.8729,  0.9266,  0.3729, -0.0271,  0.4266],
#        dtype=torch.float64)
# Grad: %f tensor([1.2970, 1.2970, 0.7328, 1.2970, 1.2970, 0.7328], dtype=torch.float64)
# -------------------------------------------------
# Epoch 85, Loss 0.270214
# Params: %f tensor([ 0.8716,  0.8716,  0.9259,  0.3716, -0.0284,  0.4259],
#        dtype=torch.float64)
# Grad: %f tensor([1.2923, 1.2923, 0.7297, 1.2923, 1.2923, 0.7297], dtype=torch.float64)
# -------------------------------------------------
# Epoch 86, Loss 0.268626
# Params: %f tensor([ 0.8703,  0.8703,  0.9252,  0.3703, -0.0297,  0.4252],
#        dtype=torch.float64)
# Grad: %f tensor([1.2876, 1.2876, 0.7267, 1.2876, 1.2876, 0.7267], dtype=torch.float64)
# -------------------------------------------------
# Epoch 87, Loss 0.267050
# Params: %f tensor([ 0.8690,  0.8690,  0.9245,  0.3690, -0.0310,  0.4245],
#        dtype=torch.float64)
# Grad: %f tensor([1.2830, 1.2830, 0.7237, 1.2830, 1.2830, 0.7237], dtype=torch.float64)
# -------------------------------------------------
# Epoch 88, Loss 0.265486
# Params: %f tensor([ 0.8677,  0.8677,  0.9237,  0.3677, -0.0323,  0.4237],
#        dtype=torch.float64)
# Grad: %f tensor([1.2783, 1.2783, 0.7207, 1.2783, 1.2783, 0.7207], dtype=torch.float64)
# -------------------------------------------------
# Epoch 89, Loss 0.263933
# Params: %f tensor([ 0.8665,  0.8665,  0.9230,  0.3665, -0.0335,  0.4230],
#        dtype=torch.float64)
# Grad: %f tensor([1.2737, 1.2737, 0.7177, 1.2737, 1.2737, 0.7177], dtype=torch.float64)
# -------------------------------------------------
# Epoch 90, Loss 0.262391
# Params: %f tensor([ 0.8652,  0.8652,  0.9223,  0.3652, -0.0348,  0.4223],
#        dtype=torch.float64)
# Grad: %f tensor([1.2691, 1.2691, 0.7147, 1.2691, 1.2691, 0.7147], dtype=torch.float64)
# -------------------------------------------------
# Epoch 91, Loss 0.260861
# Params: %f tensor([ 0.8639,  0.8639,  0.9216,  0.3639, -0.0361,  0.4216],
#        dtype=torch.float64)
# Grad: %f tensor([1.2645, 1.2645, 0.7117, 1.2645, 1.2645, 0.7117], dtype=torch.float64)
# -------------------------------------------------
# Epoch 92, Loss 0.259341
# Params: %f tensor([ 0.8627,  0.8627,  0.9209,  0.3627, -0.0373,  0.4209],
#        dtype=torch.float64)
# Grad: %f tensor([1.2600, 1.2600, 0.7087, 1.2600, 1.2600, 0.7087], dtype=torch.float64)
# -------------------------------------------------
# Epoch 93, Loss 0.257833
# Params: %f tensor([ 0.8614,  0.8614,  0.9202,  0.3614, -0.0386,  0.4202],
#        dtype=torch.float64)
# Grad: %f tensor([1.2554, 1.2554, 0.7058, 1.2554, 1.2554, 0.7058], dtype=torch.float64)
# -------------------------------------------------
# Epoch 94, Loss 0.256336
# Params: %f tensor([ 0.8602,  0.8602,  0.9195,  0.3602, -0.0398,  0.4195],
#        dtype=torch.float64)
# Grad: %f tensor([1.2509, 1.2509, 0.7028, 1.2509, 1.2509, 0.7028], dtype=torch.float64)
# -------------------------------------------------
# Epoch 95, Loss 0.254849
# Params: %f tensor([ 0.8589,  0.8589,  0.9188,  0.3589, -0.0411,  0.4188],
#        dtype=torch.float64)
# Grad: %f tensor([1.2464, 1.2464, 0.6999, 1.2464, 1.2464, 0.6999], dtype=torch.float64)
# -------------------------------------------------
# Epoch 96, Loss 0.253374
# Params: %f tensor([ 0.8577,  0.8577,  0.9181,  0.3577, -0.0423,  0.4181],
#        dtype=torch.float64)
# Grad: %f tensor([1.2419, 1.2419, 0.6969, 1.2419, 1.2419, 0.6969], dtype=torch.float64)
# -------------------------------------------------
# Epoch 97, Loss 0.251909
# Params: %f tensor([ 0.8564,  0.8564,  0.9174,  0.3564, -0.0436,  0.4174],
#        dtype=torch.float64)
# Grad: %f tensor([1.2374, 1.2374, 0.6940, 1.2374, 1.2374, 0.6940], dtype=torch.float64)
# -------------------------------------------------
# Epoch 98, Loss 0.250455
# Params: %f tensor([ 0.8552,  0.8552,  0.9167,  0.3552, -0.0448,  0.4167],
#        dtype=torch.float64)
# Grad: %f tensor([1.2329, 1.2329, 0.6911, 1.2329, 1.2329, 0.6911], dtype=torch.float64)
# -------------------------------------------------
# Epoch 99, Loss 0.249011
# Params: %f tensor([ 0.8540,  0.8540,  0.9160,  0.3540, -0.0460,  0.4160],
#        dtype=torch.float64)
# Grad: %f tensor([1.2285, 1.2285, 0.6882, 1.2285, 1.2285, 0.6882], dtype=torch.float64)
# -------------------------------------------------
# Epoch 100, Loss 0.247578
# Params: %f tensor([ 0.8528,  0.8528,  0.9153,  0.3528, -0.0472,  0.4153],
#        dtype=torch.float64)
# Grad: %f tensor([1.2240, 1.2240, 0.6853, 1.2240, 1.2240, 0.6853], dtype=torch.float64)
# -------------------------------------------------
# Epoch 101, Loss 0.246155
# Params: %f tensor([ 0.8515,  0.8515,  0.9146,  0.3515, -0.0485,  0.4146],
#        dtype=torch.float64)
# Grad: %f tensor([1.2196, 1.2196, 0.6825, 1.2196, 1.2196, 0.6825], dtype=torch.float64)
# -------------------------------------------------
# Epoch 102, Loss 0.244743
# Params: %f tensor([ 0.8503,  0.8503,  0.9140,  0.3503, -0.0497,  0.4140],
#        dtype=torch.float64)
# Grad: %f tensor([1.2152, 1.2152, 0.6796, 1.2152, 1.2152, 0.6796], dtype=torch.float64)
# -------------------------------------------------
# Epoch 103, Loss 0.243341
# Params: %f tensor([ 0.8491,  0.8491,  0.9133,  0.3491, -0.0509,  0.4133],
#        dtype=torch.float64)
# Grad: %f tensor([1.2108, 1.2108, 0.6768, 1.2108, 1.2108, 0.6768], dtype=torch.float64)
# -------------------------------------------------
# Epoch 104, Loss 0.241949
# Params: %f tensor([ 0.8479,  0.8479,  0.9126,  0.3479, -0.0521,  0.4126],
#        dtype=torch.float64)
# Grad: %f tensor([1.2064, 1.2064, 0.6739, 1.2064, 1.2064, 0.6739], dtype=torch.float64)
# -------------------------------------------------
# Epoch 105, Loss 0.240567
# Params: %f tensor([ 0.8467,  0.8467,  0.9119,  0.3467, -0.0533,  0.4119],
#        dtype=torch.float64)
# Grad: %f tensor([1.2021, 1.2021, 0.6711, 1.2021, 1.2021, 0.6711], dtype=torch.float64)
# -------------------------------------------------
# Epoch 106, Loss 0.239195
# Params: %f tensor([ 0.8455,  0.8455,  0.9113,  0.3455, -0.0545,  0.4113],
#        dtype=torch.float64)
# Grad: %f tensor([1.1977, 1.1977, 0.6683, 1.1977, 1.1977, 0.6683], dtype=torch.float64)
# -------------------------------------------------
# Epoch 107, Loss 0.237834
# Params: %f tensor([ 0.8443,  0.8443,  0.9106,  0.3443, -0.0557,  0.4106],
#        dtype=torch.float64)
# Grad: %f tensor([1.1934, 1.1934, 0.6654, 1.1934, 1.1934, 0.6654], dtype=torch.float64)
# -------------------------------------------------
# Epoch 108, Loss 0.236482
# Params: %f tensor([ 0.8431,  0.8431,  0.9099,  0.3431, -0.0569,  0.4099],
#        dtype=torch.float64)
# Grad: %f tensor([1.1891, 1.1891, 0.6626, 1.1891, 1.1891, 0.6626], dtype=torch.float64)
# -------------------------------------------------
# Epoch 109, Loss 0.235140
# Params: %f tensor([ 0.8419,  0.8419,  0.9093,  0.3419, -0.0581,  0.4093],
#        dtype=torch.float64)
# Grad: %f tensor([1.1848, 1.1848, 0.6599, 1.1848, 1.1848, 0.6599], dtype=torch.float64)
# -------------------------------------------------
# Epoch 110, Loss 0.233807
# Params: %f tensor([ 0.8408,  0.8408,  0.9086,  0.3408, -0.0592,  0.4086],
#        dtype=torch.float64)
# Grad: %f tensor([1.1805, 1.1805, 0.6571, 1.1805, 1.1805, 0.6571], dtype=torch.float64)
# -------------------------------------------------
# Epoch 111, Loss 0.232485
# Params: %f tensor([ 0.8396,  0.8396,  0.9080,  0.3396, -0.0604,  0.4080],
#        dtype=torch.float64)
# Grad: %f tensor([1.1763, 1.1763, 0.6543, 1.1763, 1.1763, 0.6543], dtype=torch.float64)
# -------------------------------------------------
# Epoch 112, Loss 0.231172
# Params: %f tensor([ 0.8384,  0.8384,  0.9073,  0.3384, -0.0616,  0.4073],
#        dtype=torch.float64)
# Grad: %f tensor([1.1720, 1.1720, 0.6515, 1.1720, 1.1720, 0.6515], dtype=torch.float64)
# -------------------------------------------------
# Epoch 113, Loss 0.229869
# Params: %f tensor([ 0.8372,  0.8372,  0.9067,  0.3372, -0.0628,  0.4067],
#        dtype=torch.float64)
# Grad: %f tensor([1.1678, 1.1678, 0.6488, 1.1678, 1.1678, 0.6488], dtype=torch.float64)
# -------------------------------------------------
# Epoch 114, Loss 0.228575
# Params: %f tensor([ 0.8361,  0.8361,  0.9060,  0.3361, -0.0639,  0.4060],
#        dtype=torch.float64)
# Grad: %f tensor([1.1636, 1.1636, 0.6460, 1.1636, 1.1636, 0.6460], dtype=torch.float64)
# -------------------------------------------------
# Epoch 115, Loss 0.227290
# Params: %f tensor([ 0.8349,  0.8349,  0.9054,  0.3349, -0.0651,  0.4054],
#        dtype=torch.float64)
# Grad: %f tensor([1.1594, 1.1594, 0.6433, 1.1594, 1.1594, 0.6433], dtype=torch.float64)
# -------------------------------------------------
# Epoch 116, Loss 0.226015
# Params: %f tensor([ 0.8338,  0.8338,  0.9047,  0.3338, -0.0662,  0.4047],
#        dtype=torch.float64)
# Grad: %f tensor([1.1552, 1.1552, 0.6406, 1.1552, 1.1552, 0.6406], dtype=torch.float64)
# -------------------------------------------------
# Epoch 117, Loss 0.224749
# Params: %f tensor([ 0.8326,  0.8326,  0.9041,  0.3326, -0.0674,  0.4041],
#        dtype=torch.float64)
# Grad: %f tensor([1.1510, 1.1510, 0.6379, 1.1510, 1.1510, 0.6379], dtype=torch.float64)
# -------------------------------------------------
# Epoch 118, Loss 0.223493
# Params: %f tensor([ 0.8315,  0.8315,  0.9035,  0.3315, -0.0685,  0.4035],
#        dtype=torch.float64)
# Grad: %f tensor([1.1469, 1.1469, 0.6352, 1.1469, 1.1469, 0.6352], dtype=torch.float64)
# -------------------------------------------------
# Epoch 119, Loss 0.222245
# Params: %f tensor([ 0.8303,  0.8303,  0.9028,  0.3303, -0.0697,  0.4028],
#        dtype=torch.float64)
# Grad: %f tensor([1.1427, 1.1427, 0.6325, 1.1427, 1.1427, 0.6325], dtype=torch.float64)
# -------------------------------------------------
# Epoch 120, Loss 0.221007
# Params: %f tensor([ 0.8292,  0.8292,  0.9022,  0.3292, -0.0708,  0.4022],
#        dtype=torch.float64)
# Grad: %f tensor([1.1386, 1.1386, 0.6298, 1.1386, 1.1386, 0.6298], dtype=torch.float64)
# -------------------------------------------------
# Epoch 121, Loss 0.219777
# Params: %f tensor([ 0.8281,  0.8281,  0.9016,  0.3281, -0.0719,  0.4016],
#        dtype=torch.float64)
# Grad: %f tensor([1.1345, 1.1345, 0.6271, 1.1345, 1.1345, 0.6271], dtype=torch.float64)
# -------------------------------------------------
# Epoch 122, Loss 0.218557
# Params: %f tensor([ 0.8269,  0.8269,  0.9010,  0.3269, -0.0731,  0.4010],
#        dtype=torch.float64)
# Grad: %f tensor([1.1304, 1.1304, 0.6245, 1.1304, 1.1304, 0.6245], dtype=torch.float64)
# -------------------------------------------------
# Epoch 123, Loss 0.217345
# Params: %f tensor([ 0.8258,  0.8258,  0.9003,  0.3258, -0.0742,  0.4003],
#        dtype=torch.float64)
# Grad: %f tensor([1.1263, 1.1263, 0.6218, 1.1263, 1.1263, 0.6218], dtype=torch.float64)
# -------------------------------------------------
# Epoch 124, Loss 0.216142
# Params: %f tensor([ 0.8247,  0.8247,  0.8997,  0.3247, -0.0753,  0.3997],
#        dtype=torch.float64)
# Grad: %f tensor([1.1223, 1.1223, 0.6192, 1.1223, 1.1223, 0.6192], dtype=torch.float64)
# -------------------------------------------------
# Epoch 125, Loss 0.214948
# Params: %f tensor([ 0.8236,  0.8236,  0.8991,  0.3236, -0.0764,  0.3991],
#        dtype=torch.float64)
# Grad: %f tensor([1.1182, 1.1182, 0.6165, 1.1182, 1.1182, 0.6165], dtype=torch.float64)
# -------------------------------------------------
# Epoch 126, Loss 0.213763
# Params: %f tensor([ 0.8224,  0.8224,  0.8985,  0.3224, -0.0776,  0.3985],
#        dtype=torch.float64)
# Grad: %f tensor([1.1142, 1.1142, 0.6139, 1.1142, 1.1142, 0.6139], dtype=torch.float64)
# -------------------------------------------------
# Epoch 127, Loss 0.212586
# Params: %f tensor([ 0.8213,  0.8213,  0.8979,  0.3213, -0.0787,  0.3979],
#        dtype=torch.float64)
# Grad: %f tensor([1.1102, 1.1102, 0.6113, 1.1102, 1.1102, 0.6113], dtype=torch.float64)
# -------------------------------------------------
# Epoch 128, Loss 0.211418
# Params: %f tensor([ 0.8202,  0.8202,  0.8973,  0.3202, -0.0798,  0.3973],
#        dtype=torch.float64)
# Grad: %f tensor([1.1062, 1.1062, 0.6087, 1.1062, 1.1062, 0.6087], dtype=torch.float64)
# -------------------------------------------------
# Epoch 129, Loss 0.210259
# Params: %f tensor([ 0.8191,  0.8191,  0.8967,  0.3191, -0.0809,  0.3967],
#        dtype=torch.float64)
# Grad: %f tensor([1.1022, 1.1022, 0.6061, 1.1022, 1.1022, 0.6061], dtype=torch.float64)
# -------------------------------------------------
# Epoch 130, Loss 0.209107
# Params: %f tensor([ 0.8180,  0.8180,  0.8961,  0.3180, -0.0820,  0.3961],
#        dtype=torch.float64)
# Grad: %f tensor([1.0982, 1.0982, 0.6035, 1.0982, 1.0982, 0.6035], dtype=torch.float64)
# -------------------------------------------------
# Epoch 131, Loss 0.207964
# Params: %f tensor([ 0.8169,  0.8169,  0.8955,  0.3169, -0.0831,  0.3955],
#        dtype=torch.float64)
# Grad: %f tensor([1.0942, 1.0942, 0.6009, 1.0942, 1.0942, 0.6009], dtype=torch.float64)
# -------------------------------------------------
# Epoch 132, Loss 0.206830
# Params: %f tensor([ 0.8158,  0.8158,  0.8949,  0.3158, -0.0842,  0.3949],
#        dtype=torch.float64)
# Grad: %f tensor([1.0903, 1.0903, 0.5984, 1.0903, 1.0903, 0.5984], dtype=torch.float64)
# -------------------------------------------------
# Epoch 133, Loss 0.205704
# Params: %f tensor([ 0.8148,  0.8148,  0.8943,  0.3148, -0.0852,  0.3943],
#        dtype=torch.float64)
# Grad: %f tensor([1.0864, 1.0864, 0.5958, 1.0864, 1.0864, 0.5958], dtype=torch.float64)
# -------------------------------------------------
# Epoch 134, Loss 0.204586
# Params: %f tensor([ 0.8137,  0.8137,  0.8937,  0.3137, -0.0863,  0.3937],
#        dtype=torch.float64)
# Grad: %f tensor([1.0824, 1.0824, 0.5933, 1.0824, 1.0824, 0.5933], dtype=torch.float64)
# -------------------------------------------------
# Epoch 135, Loss 0.203476
# Params: %f tensor([ 0.8126,  0.8126,  0.8931,  0.3126, -0.0874,  0.3931],
#        dtype=torch.float64)
# Grad: %f tensor([1.0785, 1.0785, 0.5907, 1.0785, 1.0785, 0.5907], dtype=torch.float64)
# -------------------------------------------------
# Epoch 136, Loss 0.202374
# Params: %f tensor([ 0.8115,  0.8115,  0.8925,  0.3115, -0.0885,  0.3925],
#        dtype=torch.float64)
# Grad: %f tensor([1.0746, 1.0746, 0.5882, 1.0746, 1.0746, 0.5882], dtype=torch.float64)
# -------------------------------------------------
# Epoch 137, Loss 0.201280
# Params: %f tensor([ 0.8105,  0.8105,  0.8919,  0.3105, -0.0895,  0.3919],
#        dtype=torch.float64)
# Grad: %f tensor([1.0708, 1.0708, 0.5857, 1.0708, 1.0708, 0.5857], dtype=torch.float64)
# -------------------------------------------------
# Epoch 138, Loss 0.200194
# Params: %f tensor([ 0.8094,  0.8094,  0.8913,  0.3094, -0.0906,  0.3913],
#        dtype=torch.float64)
# Grad: %f tensor([1.0669, 1.0669, 0.5832, 1.0669, 1.0669, 0.5832], dtype=torch.float64)
# -------------------------------------------------
# Epoch 139, Loss 0.199116
# Params: %f tensor([ 0.8083,  0.8083,  0.8907,  0.3083, -0.0917,  0.3907],
#        dtype=torch.float64)
# Grad: %f tensor([1.0631, 1.0631, 0.5807, 1.0631, 1.0631, 0.5807], dtype=torch.float64)
# -------------------------------------------------
# Epoch 140, Loss 0.198046
# Params: %f tensor([ 0.8073,  0.8073,  0.8902,  0.3073, -0.0927,  0.3902],
#        dtype=torch.float64)
# Grad: %f tensor([1.0592, 1.0592, 0.5782, 1.0592, 1.0592, 0.5782], dtype=torch.float64)
# -------------------------------------------------
# Epoch 141, Loss 0.196984
# Params: %f tensor([ 0.8062,  0.8062,  0.8896,  0.3062, -0.0938,  0.3896],
#        dtype=torch.float64)
# Grad: %f tensor([1.0554, 1.0554, 0.5757, 1.0554, 1.0554, 0.5757], dtype=torch.float64)
# -------------------------------------------------
# Epoch 142, Loss 0.195929
# Params: %f tensor([ 0.8052,  0.8052,  0.8890,  0.3052, -0.0948,  0.3890],
#        dtype=torch.float64)
# Grad: %f tensor([1.0516, 1.0516, 0.5732, 1.0516, 1.0516, 0.5732], dtype=torch.float64)
# -------------------------------------------------
# Epoch 143, Loss 0.194882
# Params: %f tensor([ 0.8041,  0.8041,  0.8884,  0.3041, -0.0959,  0.3884],
#        dtype=torch.float64)
# Grad: %f tensor([1.0478, 1.0478, 0.5708, 1.0478, 1.0478, 0.5708], dtype=torch.float64)
# -------------------------------------------------
# Epoch 144, Loss 0.193843
# Params: %f tensor([ 0.8031,  0.8031,  0.8879,  0.3031, -0.0969,  0.3879],
#        dtype=torch.float64)
# Grad: %f tensor([1.0440, 1.0440, 0.5683, 1.0440, 1.0440, 0.5683], dtype=torch.float64)
# -------------------------------------------------
# Epoch 145, Loss 0.192811
# Params: %f tensor([ 0.8020,  0.8020,  0.8873,  0.3020, -0.0980,  0.3873],
#        dtype=torch.float64)
# Grad: %f tensor([1.0403, 1.0403, 0.5659, 1.0403, 1.0403, 0.5659], dtype=torch.float64)
# -------------------------------------------------
# Epoch 146, Loss 0.191787
# Params: %f tensor([ 0.8010,  0.8010,  0.8867,  0.3010, -0.0990,  0.3867],
#        dtype=torch.float64)
# Grad: %f tensor([1.0365, 1.0365, 0.5634, 1.0365, 1.0365, 0.5634], dtype=torch.float64)
# -------------------------------------------------
# Epoch 147, Loss 0.190770
# Params: %f tensor([ 0.8000,  0.8000,  0.8862,  0.3000, -0.1000,  0.3862],
#        dtype=torch.float64)
# Grad: %f tensor([1.0328, 1.0328, 0.5610, 1.0328, 1.0328, 0.5610], dtype=torch.float64)
# -------------------------------------------------
# Epoch 148, Loss 0.189760
# Params: %f tensor([ 0.7989,  0.7989,  0.8856,  0.2989, -0.1011,  0.3856],
#        dtype=torch.float64)
# Grad: %f tensor([1.0291, 1.0291, 0.5586, 1.0291, 1.0291, 0.5586], dtype=torch.float64)
# -------------------------------------------------
# Epoch 149, Loss 0.188758
# Params: %f tensor([ 0.7979,  0.7979,  0.8851,  0.2979, -0.1021,  0.3851],
#        dtype=torch.float64)
# Grad: %f tensor([1.0253, 1.0253, 0.5561, 1.0253, 1.0253, 0.5561], dtype=torch.float64)
# -------------------------------------------------
# Epoch 150, Loss 0.187764
# Params: %f tensor([ 0.7969,  0.7969,  0.8845,  0.2969, -0.1031,  0.3845],
#        dtype=torch.float64)
# Grad: %f tensor([1.0217, 1.0217, 0.5537, 1.0217, 1.0217, 0.5537], dtype=torch.float64)
# -------------------------------------------------
# Epoch 151, Loss 0.186776
# Params: %f tensor([ 0.7959,  0.7959,  0.8840,  0.2959, -0.1041,  0.3840],
#        dtype=torch.float64)
# Grad: %f tensor([1.0180, 1.0180, 0.5513, 1.0180, 1.0180, 0.5513], dtype=torch.float64)
# -------------------------------------------------
# Epoch 152, Loss 0.185796
# Params: %f tensor([ 0.7948,  0.7948,  0.8834,  0.2948, -0.1052,  0.3834],
#        dtype=torch.float64)
# Grad: %f tensor([1.0143, 1.0143, 0.5490, 1.0143, 1.0143, 0.5490], dtype=torch.float64)
# -------------------------------------------------
# Epoch 153, Loss 0.184823
# Params: %f tensor([ 0.7938,  0.7938,  0.8829,  0.2938, -0.1062,  0.3829],
#        dtype=torch.float64)
# Grad: %f tensor([1.0106, 1.0106, 0.5466, 1.0106, 1.0106, 0.5466], dtype=torch.float64)
# -------------------------------------------------
# Epoch 154, Loss 0.183856
# Params: %f tensor([ 0.7928,  0.7928,  0.8823,  0.2928, -0.1072,  0.3823],
#        dtype=torch.float64)
# Grad: %f tensor([1.0070, 1.0070, 0.5442, 1.0070, 1.0070, 0.5442], dtype=torch.float64)
# -------------------------------------------------
# Epoch 155, Loss 0.182897
# Params: %f tensor([ 0.7918,  0.7918,  0.8818,  0.2918, -0.1082,  0.3818],
#        dtype=torch.float64)
# Grad: %f tensor([1.0034, 1.0034, 0.5419, 1.0034, 1.0034, 0.5419], dtype=torch.float64)
# -------------------------------------------------
# Epoch 156, Loss 0.181945
# Params: %f tensor([ 0.7908,  0.7908,  0.8812,  0.2908, -0.1092,  0.3812],
#        dtype=torch.float64)
# Grad: %f tensor([0.9998, 0.9998, 0.5395, 0.9998, 0.9998, 0.5395], dtype=torch.float64)
# -------------------------------------------------
# Epoch 157, Loss 0.181000
# Params: %f tensor([ 0.7898,  0.7898,  0.8807,  0.2898, -0.1102,  0.3807],
#        dtype=torch.float64)
# Grad: %f tensor([0.9962, 0.9962, 0.5372, 0.9962, 0.9962, 0.5372], dtype=torch.float64)
# -------------------------------------------------
# Epoch 158, Loss 0.180062
# Params: %f tensor([ 0.7888,  0.7888,  0.8802,  0.2888, -0.1112,  0.3802],
#        dtype=torch.float64)
# Grad: %f tensor([0.9926, 0.9926, 0.5348, 0.9926, 0.9926, 0.5348], dtype=torch.float64)
# -------------------------------------------------
# Epoch 159, Loss 0.179130
# Params: %f tensor([ 0.7878,  0.7878,  0.8796,  0.2878, -0.1122,  0.3796],
#        dtype=torch.float64)
# Grad: %f tensor([0.9890, 0.9890, 0.5325, 0.9890, 0.9890, 0.5325], dtype=torch.float64)
# -------------------------------------------------
# Epoch 160, Loss 0.178206
# Params: %f tensor([ 0.7869,  0.7869,  0.8791,  0.2869, -0.1131,  0.3791],
#        dtype=torch.float64)
# Grad: %f tensor([0.9854, 0.9854, 0.5302, 0.9854, 0.9854, 0.5302], dtype=torch.float64)
# -------------------------------------------------
# Epoch 161, Loss 0.177288
# Params: %f tensor([ 0.7859,  0.7859,  0.8786,  0.2859, -0.1141,  0.3786],
#        dtype=torch.float64)
# Grad: %f tensor([0.9819, 0.9819, 0.5279, 0.9819, 0.9819, 0.5279], dtype=torch.float64)
# -------------------------------------------------
# Epoch 162, Loss 0.176376
# Params: %f tensor([ 0.7849,  0.7849,  0.8781,  0.2849, -0.1151,  0.3781],
#        dtype=torch.float64)
# Grad: %f tensor([0.9783, 0.9783, 0.5256, 0.9783, 0.9783, 0.5256], dtype=torch.float64)
# -------------------------------------------------
# Epoch 163, Loss 0.175472
# Params: %f tensor([ 0.7839,  0.7839,  0.8775,  0.2839, -0.1161,  0.3775],
#        dtype=torch.float64)
# Grad: %f tensor([0.9748, 0.9748, 0.5233, 0.9748, 0.9748, 0.5233], dtype=torch.float64)
# -------------------------------------------------
# Epoch 164, Loss 0.174574
# Params: %f tensor([ 0.7830,  0.7830,  0.8770,  0.2830, -0.1170,  0.3770],
#        dtype=torch.float64)
# Grad: %f tensor([0.9713, 0.9713, 0.5210, 0.9713, 0.9713, 0.5210], dtype=torch.float64)
# -------------------------------------------------
# Epoch 165, Loss 0.173682
# Params: %f tensor([ 0.7820,  0.7820,  0.8765,  0.2820, -0.1180,  0.3765],
#        dtype=torch.float64)
# Grad: %f tensor([0.9678, 0.9678, 0.5187, 0.9678, 0.9678, 0.5187], dtype=torch.float64)
# -------------------------------------------------
# Epoch 166, Loss 0.172797
# Params: %f tensor([ 0.7810,  0.7810,  0.8760,  0.2810, -0.1190,  0.3760],
#        dtype=torch.float64)
# Grad: %f tensor([0.9643, 0.9643, 0.5164, 0.9643, 0.9643, 0.5164], dtype=torch.float64)
# -------------------------------------------------
# Epoch 167, Loss 0.171919
# Params: %f tensor([ 0.7801,  0.7801,  0.8755,  0.2801, -0.1199,  0.3755],
#        dtype=torch.float64)
# Grad: %f tensor([0.9608, 0.9608, 0.5142, 0.9608, 0.9608, 0.5142], dtype=torch.float64)
# -------------------------------------------------
# Epoch 168, Loss 0.171046
# Params: %f tensor([ 0.7791,  0.7791,  0.8749,  0.2791, -0.1209,  0.3749],
#        dtype=torch.float64)
# Grad: %f tensor([0.9574, 0.9574, 0.5119, 0.9574, 0.9574, 0.5119], dtype=torch.float64)
# -------------------------------------------------
# Epoch 169, Loss 0.170180
# Params: %f tensor([ 0.7781,  0.7781,  0.8744,  0.2781, -0.1219,  0.3744],
#        dtype=torch.float64)
# Grad: %f tensor([0.9539, 0.9539, 0.5097, 0.9539, 0.9539, 0.5097], dtype=torch.float64)
# -------------------------------------------------
# Epoch 170, Loss 0.169321
# Params: %f tensor([ 0.7772,  0.7772,  0.8739,  0.2772, -0.1228,  0.3739],
#        dtype=torch.float64)
# Grad: %f tensor([0.9505, 0.9505, 0.5075, 0.9505, 0.9505, 0.5075], dtype=torch.float64)
# -------------------------------------------------
# Epoch 171, Loss 0.168468
# Params: %f tensor([ 0.7763,  0.7763,  0.8734,  0.2763, -0.1237,  0.3734],
#        dtype=torch.float64)
# Grad: %f tensor([0.9471, 0.9471, 0.5052, 0.9471, 0.9471, 0.5052], dtype=torch.float64)
# -------------------------------------------------
# Epoch 172, Loss 0.167621
# Params: %f tensor([ 0.7753,  0.7753,  0.8729,  0.2753, -0.1247,  0.3729],
#        dtype=torch.float64)
# Grad: %f tensor([0.9437, 0.9437, 0.5030, 0.9437, 0.9437, 0.5030], dtype=torch.float64)
# -------------------------------------------------
# Epoch 173, Loss 0.166780
# Params: %f tensor([ 0.7744,  0.7744,  0.8724,  0.2744, -0.1256,  0.3724],
#        dtype=torch.float64)
# Grad: %f tensor([0.9403, 0.9403, 0.5008, 0.9403, 0.9403, 0.5008], dtype=torch.float64)
# -------------------------------------------------
# Epoch 174, Loss 0.165945
# Params: %f tensor([ 0.7734,  0.7734,  0.8719,  0.2734, -0.1266,  0.3719],
#        dtype=torch.float64)
# Grad: %f tensor([0.9369, 0.9369, 0.4986, 0.9369, 0.9369, 0.4986], dtype=torch.float64)
# -------------------------------------------------
# Epoch 175, Loss 0.165116
# Params: %f tensor([ 0.7725,  0.7725,  0.8714,  0.2725, -0.1275,  0.3714],
#        dtype=torch.float64)
# Grad: %f tensor([0.9335, 0.9335, 0.4964, 0.9335, 0.9335, 0.4964], dtype=torch.float64)
# -------------------------------------------------
# Epoch 176, Loss 0.164293
# Params: %f tensor([ 0.7716,  0.7716,  0.8709,  0.2716, -0.1284,  0.3709],
#        dtype=torch.float64)
# Grad: %f tensor([0.9301, 0.9301, 0.4942, 0.9301, 0.9301, 0.4942], dtype=torch.float64)
# -------------------------------------------------
# Epoch 177, Loss 0.163477
# Params: %f tensor([ 0.7706,  0.7706,  0.8704,  0.2706, -0.1294,  0.3704],
#        dtype=torch.float64)
# Grad: %f tensor([0.9268, 0.9268, 0.4920, 0.9268, 0.9268, 0.4920], dtype=torch.float64)
# -------------------------------------------------
# Epoch 178, Loss 0.162666
# Params: %f tensor([ 0.7697,  0.7697,  0.8699,  0.2697, -0.1303,  0.3699],
#        dtype=torch.float64)
# Grad: %f tensor([0.9235, 0.9235, 0.4899, 0.9235, 0.9235, 0.4899], dtype=torch.float64)
# -------------------------------------------------
# Epoch 179, Loss 0.161861
# Params: %f tensor([ 0.7688,  0.7688,  0.8695,  0.2688, -0.1312,  0.3695],
#        dtype=torch.float64)
# Grad: %f tensor([0.9201, 0.9201, 0.4877, 0.9201, 0.9201, 0.4877], dtype=torch.float64)
# -------------------------------------------------
# Epoch 180, Loss 0.161062
# Params: %f tensor([ 0.7679,  0.7679,  0.8690,  0.2679, -0.1321,  0.3690],
#        dtype=torch.float64)
# Grad: %f tensor([0.9168, 0.9168, 0.4856, 0.9168, 0.9168, 0.4856], dtype=torch.float64)
# -------------------------------------------------
# Epoch 181, Loss 0.160269
# Params: %f tensor([ 0.7670,  0.7670,  0.8685,  0.2670, -0.1330,  0.3685],
#        dtype=torch.float64)
# Grad: %f tensor([0.9135, 0.9135, 0.4834, 0.9135, 0.9135, 0.4834], dtype=torch.float64)
# -------------------------------------------------
# Epoch 182, Loss 0.159482
# Params: %f tensor([ 0.7661,  0.7661,  0.8680,  0.2661, -0.1339,  0.3680],
#        dtype=torch.float64)
# Grad: %f tensor([0.9102, 0.9102, 0.4813, 0.9102, 0.9102, 0.4813], dtype=torch.float64)
# -------------------------------------------------
# Epoch 183, Loss 0.158700
# Params: %f tensor([ 0.7651,  0.7651,  0.8675,  0.2651, -0.1349,  0.3675],
#        dtype=torch.float64)
# Grad: %f tensor([0.9070, 0.9070, 0.4791, 0.9070, 0.9070, 0.4791], dtype=torch.float64)
# -------------------------------------------------
# Epoch 184, Loss 0.157924
# Params: %f tensor([ 0.7642,  0.7642,  0.8671,  0.2642, -0.1358,  0.3671],
#        dtype=torch.float64)
# Grad: %f tensor([0.9037, 0.9037, 0.4770, 0.9037, 0.9037, 0.4770], dtype=torch.float64)
# -------------------------------------------------
# Epoch 185, Loss 0.157154
# Params: %f tensor([ 0.7633,  0.7633,  0.8666,  0.2633, -0.1367,  0.3666],
#        dtype=torch.float64)
# Grad: %f tensor([0.9004, 0.9004, 0.4749, 0.9004, 0.9004, 0.4749], dtype=torch.float64)
# -------------------------------------------------
# Epoch 186, Loss 0.156389
# ...
# -------------------------------------------------
# Epoch 4944, Loss 0.070619
# Params: %f tensor([ 0.4610,  0.4610,  1.2544, -0.0390, -0.4390,  0.7544],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1279,  0.0139,  0.0139, -0.1279],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4945, Loss 0.070626
# Params: %f tensor([ 0.4610,  0.4610,  1.2545, -0.0390, -0.4390,  0.7545],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1279,  0.0139,  0.0139, -0.1279],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4946, Loss 0.070632
# Params: %f tensor([ 0.4610,  0.4610,  1.2547, -0.0390, -0.4390,  0.7547],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4947, Loss 0.070638
# Params: %f tensor([ 0.4610,  0.4610,  1.2548, -0.0390, -0.4390,  0.7548],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4948, Loss 0.070645
# Params: %f tensor([ 0.4610,  0.4610,  1.2549, -0.0390, -0.4390,  0.7549],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4949, Loss 0.070651
# Params: %f tensor([ 0.4610,  0.4610,  1.2550, -0.0390, -0.4390,  0.7550],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4950, Loss 0.070657
# Params: %f tensor([ 0.4610,  0.4610,  1.2552, -0.0390, -0.4390,  0.7552],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4951, Loss 0.070664
# Params: %f tensor([ 0.4609,  0.4609,  1.2553, -0.0391, -0.4391,  0.7553],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4952, Loss 0.070670
# Params: %f tensor([ 0.4609,  0.4609,  1.2554, -0.0391, -0.4391,  0.7554],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4953, Loss 0.070676
# Params: %f tensor([ 0.4609,  0.4609,  1.2555, -0.0391, -0.4391,  0.7555],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4954, Loss 0.070683
# Params: %f tensor([ 0.4609,  0.4609,  1.2557, -0.0391, -0.4391,  0.7557],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4955, Loss 0.070689
# Params: %f tensor([ 0.4609,  0.4609,  1.2558, -0.0391, -0.4391,  0.7558],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4956, Loss 0.070695
# Params: %f tensor([ 0.4609,  0.4609,  1.2559, -0.0391, -0.4391,  0.7559],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4957, Loss 0.070702
# Params: %f tensor([ 0.4609,  0.4609,  1.2561, -0.0391, -0.4391,  0.7561],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4958, Loss 0.070708
# Params: %f tensor([ 0.4608,  0.4608,  1.2562, -0.0392, -0.4392,  0.7562],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4959, Loss 0.070714
# Params: %f tensor([ 0.4608,  0.4608,  1.2563, -0.0392, -0.4392,  0.7563],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4960, Loss 0.070721
# Params: %f tensor([ 0.4608,  0.4608,  1.2564, -0.0392, -0.4392,  0.7564],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4961, Loss 0.070727
# Params: %f tensor([ 0.4608,  0.4608,  1.2566, -0.0392, -0.4392,  0.7566],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1280,  0.0139,  0.0139, -0.1280],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4962, Loss 0.070733
# Params: %f tensor([ 0.4608,  0.4608,  1.2567, -0.0392, -0.4392,  0.7567],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4963, Loss 0.070740
# Params: %f tensor([ 0.4608,  0.4608,  1.2568, -0.0392, -0.4392,  0.7568],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4964, Loss 0.070746
# Params: %f tensor([ 0.4608,  0.4608,  1.2570, -0.0392, -0.4392,  0.7570],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4965, Loss 0.070752
# Params: %f tensor([ 0.4608,  0.4608,  1.2571, -0.0392, -0.4392,  0.7571],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4966, Loss 0.070759
# Params: %f tensor([ 0.4607,  0.4607,  1.2572, -0.0393, -0.4393,  0.7572],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4967, Loss 0.070765
# Params: %f tensor([ 0.4607,  0.4607,  1.2573, -0.0393, -0.4393,  0.7573],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4968, Loss 0.070771
# Params: %f tensor([ 0.4607,  0.4607,  1.2575, -0.0393, -0.4393,  0.7575],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4969, Loss 0.070778
# Params: %f tensor([ 0.4607,  0.4607,  1.2576, -0.0393, -0.4393,  0.7576],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4970, Loss 0.070784
# Params: %f tensor([ 0.4607,  0.4607,  1.2577, -0.0393, -0.4393,  0.7577],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4971, Loss 0.070790
# Params: %f tensor([ 0.4607,  0.4607,  1.2579, -0.0393, -0.4393,  0.7579],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4972, Loss 0.070797
# Params: %f tensor([ 0.4607,  0.4607,  1.2580, -0.0393, -0.4393,  0.7580],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4973, Loss 0.070803
# Params: %f tensor([ 0.4606,  0.4606,  1.2581, -0.0394, -0.4394,  0.7581],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4974, Loss 0.070809
# Params: %f tensor([ 0.4606,  0.4606,  1.2582, -0.0394, -0.4394,  0.7582],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4975, Loss 0.070816
# Params: %f tensor([ 0.4606,  0.4606,  1.2584, -0.0394, -0.4394,  0.7584],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4976, Loss 0.070822
# Params: %f tensor([ 0.4606,  0.4606,  1.2585, -0.0394, -0.4394,  0.7585],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4977, Loss 0.070828
# Params: %f tensor([ 0.4606,  0.4606,  1.2586, -0.0394, -0.4394,  0.7586],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4978, Loss 0.070835
# Params: %f tensor([ 0.4606,  0.4606,  1.2588, -0.0394, -0.4394,  0.7588],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1281,  0.0139,  0.0139, -0.1281],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4979, Loss 0.070841
# Params: %f tensor([ 0.4606,  0.4606,  1.2589, -0.0394, -0.4394,  0.7589],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4980, Loss 0.070847
# Params: %f tensor([ 0.4605,  0.4605,  1.2590, -0.0395, -0.4395,  0.7590],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4981, Loss 0.070854
# Params: %f tensor([ 0.4605,  0.4605,  1.2591, -0.0395, -0.4395,  0.7591],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4982, Loss 0.070860
# Params: %f tensor([ 0.4605,  0.4605,  1.2593, -0.0395, -0.4395,  0.7593],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4983, Loss 0.070866
# Params: %f tensor([ 0.4605,  0.4605,  1.2594, -0.0395, -0.4395,  0.7594],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4984, Loss 0.070873
# Params: %f tensor([ 0.4605,  0.4605,  1.2595, -0.0395, -0.4395,  0.7595],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4985, Loss 0.070879
# Params: %f tensor([ 0.4605,  0.4605,  1.2596, -0.0395, -0.4395,  0.7596],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4986, Loss 0.070885
# Params: %f tensor([ 0.4605,  0.4605,  1.2598, -0.0395, -0.4395,  0.7598],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4987, Loss 0.070892
# Params: %f tensor([ 0.4604,  0.4604,  1.2599, -0.0396, -0.4396,  0.7599],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4988, Loss 0.070898
# Params: %f tensor([ 0.4604,  0.4604,  1.2600, -0.0396, -0.4396,  0.7600],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4989, Loss 0.070904
# Params: %f tensor([ 0.4604,  0.4604,  1.2602, -0.0396, -0.4396,  0.7602],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4990, Loss 0.070911
# Params: %f tensor([ 0.4604,  0.4604,  1.2603, -0.0396, -0.4396,  0.7603],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4991, Loss 0.070917
# Params: %f tensor([ 0.4604,  0.4604,  1.2604, -0.0396, -0.4396,  0.7604],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4992, Loss 0.070924
# Params: %f tensor([ 0.4604,  0.4604,  1.2605, -0.0396, -0.4396,  0.7605],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4993, Loss 0.070930
# Params: %f tensor([ 0.4604,  0.4604,  1.2607, -0.0396, -0.4396,  0.7607],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4994, Loss 0.070936
# Params: %f tensor([ 0.4603,  0.4603,  1.2608, -0.0397, -0.4397,  0.7608],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4995, Loss 0.070943
# Params: %f tensor([ 0.4603,  0.4603,  1.2609, -0.0397, -0.4397,  0.7609],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1282,  0.0139,  0.0139, -0.1282],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4996, Loss 0.070949
# Params: %f tensor([ 0.4603,  0.4603,  1.2611, -0.0397, -0.4397,  0.7611],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1283,  0.0139,  0.0139, -0.1283],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4997, Loss 0.070955
# Params: %f tensor([ 0.4603,  0.4603,  1.2612, -0.0397, -0.4397,  0.7612],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1283,  0.0139,  0.0139, -0.1283],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4998, Loss 0.070962
# Params: %f tensor([ 0.4603,  0.4603,  1.2613, -0.0397, -0.4397,  0.7613],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1283,  0.0139,  0.0139, -0.1283],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 4999, Loss 0.070968
# Params: %f tensor([ 0.4603,  0.4603,  1.2614, -0.0397, -0.4397,  0.7614],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1283,  0.0139,  0.0139, -0.1283],
#        dtype=torch.float64)
# -------------------------------------------------
# Epoch 5000, Loss 0.070974
# Params: %f tensor([ 0.4603,  0.4603,  1.2616, -0.0397, -0.4397,  0.7616],
#        dtype=torch.float64)
# Grad: %f tensor([ 0.0139,  0.0139, -0.1283,  0.0139,  0.0139, -0.1283],
#        dtype=torch.float64)
# -------------------------------------------------
# tensor([ 0.4603,  0.4603,  1.2616, -0.0397, -0.4397,  0.7616],
#        dtype=torch.float64)

# %%
Ex = [0.5937,  0.5937,  0.7912,  0.0937, -0.3063,  0.2912]
Ex = torch.tensor(Ex).reshape(6,1)

X1_t = np.array(test.area)
X2_t = np.array(test.bedrooms)
X3_t = np.array(test.bathrooms)
X4_t = np.array(test.stories)
X5_t = np.array(test.parking)

X0_t= np.ones(test.size)

X = np.vstack([X0_t,X1_t,X2_t,X3_t,X4_t,X5_t])
X = X.T
X = np.array(X)   
x = scaler.fit_transform(X)
X= x
X

p = 300
while(p>0):
    M = test[p,:]  #13300000
    Wye =  np.matmul(M,Ex)
    print('Truth: %f'%Y[p])
    print('Pred: %f'%Wye)
    print('--------------------------------------------------------------')
    p=p-1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(300, slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [630], in <cell line: 4>()
#       3 p = 300
#       4 while(p>0):
# ----> 5     M = test[p,:]  #13300000
#       6     Wye =  np.matmul(M,Ex)
#       7     print('Truth: %f'%Y[p])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (300, slice(None, None, None))

# %%
pyplot.plot(Y)
pyplot.plot()
